# %% [markdown]
# <a href="https://colab.research.google.com/github/Tarunagg1/Letsupgrade_DataScience/blob/main/projectdatascience.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#1. Question 1
data = pd.read_csv('data1.csv')
data
# Out:
#                   Id         groupId  ... winPoints  winPlacePerc
# 0     2f262dd9795e60  78437bcd91d40e  ...      1470        0.0000
# 1     a32847cf5bf34b  85b7ce5a12e10b  ...      1531        0.2222
# 2     1b1900a9990396  edf80d6523380a  ...         0        0.8571
# 3     f589dd03b60bf2  804ab5e5585558  ...         0        0.3462
# 4     c23c4cc5b78b35  b3e2cd169ed920  ...      1557        0.0690
# ...              ...             ...  ...       ...           ...
# 9995  ef4f474acd8e85  2eca2a8391f75d  ...      1471        0.8333
# 9996  cf0bf82fb4d80e  2eaf2765f93adb  ...      1500        0.7174
# 9997  a0a31a0b1dcbe1  8d50c64ccc5071  ...      1434        0.2083
# 9998  f6874657399d69  d31843d7e62ccb  ...      1534        0.2449
# 9999  90359b0b8f8b0d  61d5b1bb8da43f  ...         0        0.1875
#
# [10000 rows x 29 columns]

# %%
Question 2
dataty = data.dtypes
dataty
# Out:
#   File "<ipython-input-10-f3e849927477>", line 1
#     Question 2
#              ^
# SyntaxError: invalid syntax

# %%
Question 3
datasummery = data.describe();
datasummery
# Out:
#   File "<ipython-input-11-2d1a517a150d>", line 1
#     Question 3
#              ^
# SyntaxError: invalid syntax

# %%
# Question 4
avg = data['kills'].mean()
print("The avg salery kill is: ",avg)
# Out:
# The avg salery kill is:  0.9134

# %%
#5 99% of people have how many kills?
nn_per = data["kills"].quantile(0.99)
print("99% of people have",nn_per,"kills")
# Out:
# 99% of people have 7.0 kills

# %%
#6 The most kills ever recorded are how much?
max = data['kills'].max();
print("The max kills is: ",max)
# Out:
# The max kills is:  35

# %%
#7 Print all the columns of the dataframe
print(data.columns)
# Out:
# Index(['Id', 'groupId', 'matchId', 'assists', 'boosts', 'damageDealt', 'DBNOs',
#        'headshotKills', 'heals', 'killPlace', 'killPoints', 'kills',
#        'killStreaks', 'longestKill', 'matchDuration', 'matchType', 'maxPlace',
#        'numGroups', 'rankPoints', 'revives', 'rideDistance', 'roadKills',
#        'swimDistance', 'teamKills', 'vehicleDestroys', 'walkDistance',
#        'weaponsAcquired', 'winPoints', 'winPlacePerc'],
#       dtype='object')

# %%
#8 Comment on distribution of the match's duration. Use seaborn
sns.distplot( data['matchDuration'] )
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#9 Comment on distribution of the walk distance. Use seaborn
sns.distplot(data['walkDistance'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#10 Plot distribution of the match's duration vs walk distance one below the other.
# %matplotlib inline
plt.style.use('classic')
plt.figure()

# plot the matchDuration
plt.subplot(2,1,1)
plt.plot(data["matchDuration"],"-")
plt.xlabel("Match Duration")
plt.ylabel("Match Duration")

# plot the walkDistance
plt.subplot(2,1,2)
plt.plot(data['walkDistance'],'--')
plt.xlabel("Match walkDistance")
plt.ylabel("Match walkDistance")
# Out:
# Text(0, 0.5, 'Match walkDistance')

# %%
#11 Plot distribution of the match's duration vs walk distance side by side

# %matplotlib inline
plt.style.use('classic')
plt.figure(figsize=(10,5))

# ploting for matchDuration
plt.subplot(1,2,1)
plt.plot(data["matchDuration"])
plt.xlabel("Match Duration")
plt.ylabel("Match Duration")

# ploting for walkDistance
plt.subplot(1,2,2)
plt.plot(data["walkDistance"])
plt.xlabel("Walk Distance")
plt.ylabel("Walk Distance")
# Out:
# Text(0, 0.5, 'Walk Distance')

# %%
# 12. Pairplot the dataframe. Comment on kills vs damage dealt, Comment on maxPlace vs numGroups.
col=["kills", "damageDealt", "maxPlace", "numGroups"]
sns.pairplot(data[col].sample(700), size = 2.5, kind="reg", diag_kind="kde")
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:1912: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#13 How many unique values are there in 'matchType' and what are their counts?
uni = pd.unique(data['matchType'])
print("\nUnique value in matchType is :",uni)
n_uni = uni.size
print("\nCount of unique value in matchType is :",n_uni)
# Out:
# Unique value in matchType is : ['squad-fpp' 'squad' 'duo-fpp' 'solo-fpp' 'duo' 'solo' 'crashfpp'
#  'flaretpp' 'normal-squad-fpp' 'normal-duo-fpp' 'flarefpp' 'normal-squad'
#  'normal-solo-fpp' 'crashtpp']
#
# Count of unique value in matchType is : 14

# %%
#14 Plot a barplot of ‘matchType’ vs 'killPoints'. Write your inferences.
sns.barplot(data['matchType'],data['killPoints'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#15 Plot a barplot of ‘matchType’ vs ‘weaponsAcquired’. Write your inferences
sns.barplot(data['matchType'],data['weaponsAcquired'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#16 Find the Categorical columns.

cat_col = data.select_dtypes('category').columns 
cat_col
# Out:
# Index([], dtype='object')

# %%
#17 Plot a boxplot of ‘matchType’ vs ‘winPlacePerc’. Write your inferences
sns.boxplot(data['matchType'],data['winPlacePerc'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#18 Plot a boxplot of ‘matchType’ vs ‘matchDuration’. Write your inferences

sns.boxplot(x='matchType', y='matchDuration', data=data);

# %%
#19 Change the orientation of the above plot to horizontal.

sns.boxplot( x='matchDuration', y='matchType',data=data);

# %%
#20 Add a new column called ‘KILL’ which contains the sum of following columns viz. headshotKills, teamKills, roadKills.
data['KILL'] = data['headshotKills'] + data['teamKills'] + data['roadKills']
data['KILL']
# Out:
# 0       0
# 1       1
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    0
# 9998    0
# 9999    0
# Name: KILL, Length: 10000, dtype: int64

# %%
#21 Round off column ‘winPlacePerc’ to 2 decimals
data['winPlacePerc'].round(decimals=2)
# Out:
# 0       0.00
# 1       0.22
# 2       0.86
# 3       0.35
# 4       0.07
#         ...
# 9995    0.83
# 9996    0.72
# 9997    0.21
# 9998    0.24
# 9999    0.19
# Name: winPlacePerc, Length: 10000, dtype: float64

# %%
#22 Take a sample of size 50 from the column damageDealt for 100 times and calculate its mean. Plot it on a histogram and comment on its distributio
mean = []

for i in range(100):
  
  for x in range(0,1001,50):
    
    mean1 = data['damageDealt'].head(x).mean()
    mean.append(mean1)
 
sns.histplot(data=data['damageDealt'], x=mean)
